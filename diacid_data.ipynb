# %%
import pandas as pd

# %%
csv_url = "https://github.com/scbgroup/diacid_data/blob/main/diacid_data.csv?raw=true"
df = pd.read_csv(csv_url)
df.head()
# Out:
#     common_name  chemspider id  pubchem id               IUPAC name  \
# 0   Formic Acid            278         284              Formic acid
# 1   Acetic acid            171         176             Acetic acid
# 2   Oxalic acid            946         971         ethanedioic acid
# 3  Malonic acid            844         867        propanedioic acid
# 4  Fumaric acid       10197150      444972  (E)-but-2-enedioic acid
#
#    molecular_weight   C number  \
# 0           46.0250          1
# 1           60.0520          2
# 2           90.0349          2
# 3          104.0615          3
# 4          116.0722          4
#
#                                                image               smiles  \
# 0  ![|200](http://www.chemspider.com/ImagesHandle...               C(=O)O
# 1  ![|200](http://www.chemspider.com/ImagesHandle...              CC(=O)O
# 2  ![|200](http://www.chemspider.com/ImagesHandle...       C(=O)(C(=O)O)O
# ...
